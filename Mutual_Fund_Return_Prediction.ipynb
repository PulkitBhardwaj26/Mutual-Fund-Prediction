# %%
import pandas as pd

# Clean the annual returns file
def clean_annual_file(input_path, output_path):
    # Read the file, using second row as header
    df = pd.read_excel(input_path, header=1)

    # Get all columns
    all_columns = df.columns.tolist()

    # Find the year columns (2024-2014) - they should be after "Scheme Name" and some other columns
    year_columns = [col for col in all_columns if str(col).isdigit() and 2014 <= int(col) <= 2024]

    # Select only Scheme Name and the year columns
    required_cols = ['Scheme Name'] + sorted(year_columns, reverse=True)
    df = df[required_cols]

    # Replace '-' with None
    df = df.replace('-', None)

    # Save cleaned file
    df.to_excel(output_path, index=False)
    print(f"Cleaned annual file saved with columns: {required_cols}")

# Clean the monthly returns file
def clean_monthly_file(input_path, output_path):
    df = pd.read_excel(input_path, header=1)

    # Manually specify the exact monthly columns needed
    monthly_cols = ["May'25", "Apr'25", "Mar'25", "Feb'25",
                   "Jan'25", "Dec'24", "Nov'24", "Oct'24",
                   "Sep'24", "Aug'24", "Jul'24"]

    # Verify these columns exist
    available_cols = [col for col in monthly_cols if col in df.columns]

    # Select only Scheme Name and available monthly columns
    df = df[['Scheme Name'] + available_cols]
    df.to_excel(output_path, index=False)

# File paths
annual_input = '/content/Annual Returns - Mutual fund screener Mutual Fund Screening and Analysis Tool - Moneycontrol.com.xlsx'
monthly_input = '/content/Monthly Returns - Mutual fund screener Mutual Fund Screening and Analysis Tool - Moneycontrol.com.xlsx'

annual_output = 'cleaned_annual_returns.xlsx'
monthly_output = 'cleaned_monthly_returns.xlsx'

# Clean both files
clean_annual_file(annual_input, annual_output)
clean_monthly_file(monthly_input, monthly_output)
# Out:
# Cleaned annual file saved with columns: ['Scheme Name', 2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014]

# %%
# import numpy as np
# import pandas as pd
# import tensorflow as tf
# from tensorflow.keras import layers, models
# from sklearn.preprocessing import MinMaxScaler

# # Load data (WITHOUT setting index during read)
# annual_df = pd.read_excel('cleaned_annual_returns.xlsx')
# monthly_df = pd.read_excel('cleaned_monthly_returns.xlsx')

# # Explicitly set index after loading
# annual_df = annual_df.set_index('Scheme Name')
# monthly_df = monthly_df.set_index('Scheme Name')

# # Verify data loading
# print("Annual Data Sample:")
# print(annual_df.head())
# print("\nMonthly Data Sample:")
# print(monthly_df.head())

# # Prepare sequences for each fund
# results = []
# for fund_name in annual_df.index:
#     try:
#         # Get annual and monthly data for this fund
#         annual_data = annual_df.loc[fund_name].values  # Gets all annual returns
#         monthly_data = monthly_df.loc[fund_name, :"Jul'24"].values  # Gets all monthly returns except May'25

#         # Combine features and get target
#         X = np.concatenate([annual_data, monthly_data])
#         y = monthly_df.loc[fund_name, "May'25"]

#         # Skip if any missing data
#         if np.isnan(X).any() or np.isnan(y):
#             continue

#         # Normalize
#         scaler = MinMaxScaler()
#         X_scaled = scaler.fit_transform(X.reshape(-1, 1)).flatten()
#         y_scaled = scaler.transform([[y]]).flatten()[0]

#         # Reshape for TFT (1 sample, timesteps, 1 feature)
#         X_reshaped = X_scaled.reshape(1, len(X), 1)

#         # Build simple TFT model
#         inputs = layers.Input(shape=(len(X), 1))
#         x = layers.LSTM(32, return_sequences=True)(inputs)
#         x = layers.LSTM(16)(x)
#         x = layers.Dense(8, activation='relu')(x)
#         outputs = layers.Dense(1)(x)
#         model = models.Model(inputs, outputs)
#         model.compile(optimizer='adam', loss='mse')

#         # Train (just on this fund's data)
#         model.fit(X_reshaped, np.array([y_scaled]), epochs=50, verbose=0)

#         # Predict
#         pred_scaled = model.predict(X_reshaped, verbose=0)[0][0]
#         pred = scaler.inverse_transform([[pred_scaled]])[0][0]

#         results.append({
#             'Fund': fund_name,
#             'Actual': y,
#             'Predicted': pred,
#             'Error': abs(pred - y)
#         })
#     except Exception as e:
#         print(f"Skipping {fund_name} due to error: {str(e)}")
#         continue

# # Create and display results
# if results:
#     results_df = pd.DataFrame(results)
#     print("\nPrediction Results:")
#     print(results_df[['Fund', 'Actual', 'Predicted', 'Error']].sort_values('Error'))

#     mae = results_df['Error'].mean()
#     print(f"\nMean Absolute Error: {mae:.4f}")
# else:
#     print("No valid funds processed - check data loading")
# Out:
# Annual Data Sample:
#                                                       2024    2023    2022  \
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth              0.1960  0.3809  0.1363
# Invesco India Contra Fund - Direct Plan - Growth    0.3597  0.2958  0.0509
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth  0.2256  0.2672  0.0773
# Franklin India ELSS Tax Saver Fund - Direct Pla...  0.2321  0.3236  0.0627
# HDFC ELSS Tax saver - Direct Plan - Growth          0.2196  0.3348  0.1114
#
#                                                       2021    2020    2019  \
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth              0.4911  0.3061 -0.0034
# Invesco India Contra Fund - Direct Plan - Growth    0.2949  0.2220  0.0710
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth  0.2354  0.1343 -0.0072
# Franklin India ELSS Tax Saver Fund - Direct Pla...  0.3576  0.1055  0.0633
# HDFC ELSS Tax saver - Direct Plan - Growth          0.3429  0.0586  0.0401
#
#                                                       2018    2017    2016  \
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth             -0.1355  0.4106  0.0240
# Invesco India Contra Fund - Direct Plan - Growth   -0.0132  0.4811  0.0795
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth  0.0104  0.2226  0.1235
# Franklin India ELSS Tax Saver Fund - Direct Pla... -0.0150  0.3048  0.0516
# HDFC ELSS Tax saver - Direct Plan - Growth         -0.0970  0.3961  0.0749
#
#                                                       2015    2014
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth              0.0012  0.4830
# Invesco India Contra Fund - Direct Plan - Growth    0.0525  0.6460
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth  0.0226  0.4013
# Franklin India ELSS Tax Saver Fund - Direct Pla...  0.0469  0.5784
# HDFC ELSS Tax saver - Direct Plan - Growth         -0.0607  0.5685
#
# Monthly Data Sample:
#                                                     May'25  Apr'25  Mar'25  \
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth              0.0236  0.0360  0.0507
# Invesco India Contra Fund - Direct Plan - Growth    0.0301  0.0516  0.0716
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth  0.0279  0.0384  0.0388
# Franklin India ELSS Tax Saver Fund - Direct Pla...  0.0241  0.0563  0.0647
# HDFC ELSS Tax saver - Direct Plan - Growth          0.0158  0.0564  0.0646
#
#                                                     Feb'25  Jan'25  Dec'24  \
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth             -0.0620 -0.0334 -0.0178
# Invesco India Contra Fund - Direct Plan - Growth   -0.0775 -0.0667 -0.0015
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth -0.0608 -0.0174 -0.0153
# Franklin India ELSS Tax Saver Fund - Direct Pla... -0.0686 -0.0559 -0.0014
# HDFC ELSS Tax saver - Direct Plan - Growth         -0.0499 -0.0257 -0.0136
#
#                                                     Nov'24  Oct'24  Sep'24  \
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth              0.0052 -0.0579  0.0130
# Invesco India Contra Fund - Direct Plan - Growth    0.0066 -0.0537  0.0301
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth  0.0089 -0.0432  0.0121
# Franklin India ELSS Tax Saver Fund - Direct Pla...  0.0109 -0.0527  0.0200
# HDFC ELSS Tax saver - Direct Plan - Growth          0.0007 -0.0506  0.0230
#
#                                                     Aug'24  Jul'24
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth              0.0100  0.0434
# Invesco India Contra Fund - Direct Plan - Growth    0.0293  0.0595
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth  0.0242  0.0296
# Franklin India ELSS Tax Saver Fund - Direct Pla...  0.0206  0.0399
# HDFC ELSS Tax saver - Direct Plan - Growth          0.0194  0.0290
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7a30d75afd80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7a30d72489a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#
# 50  Bank of India Manufacturing & Infrastructure F...  0.0779   0.085112
# 17                JM Focused Fund - (Direct) - Growth  0.0382   0.030050
# 47  Aditya Birla Sun Life India GenNext Fund - Dir...  0.0135   0.005030
# 40   Motilal Oswal Midcap Fund - Direct Plan - Growth  0.0546   0.063237
# 53   HSBC Business Cycles Fund - Direct Plan - Growth  0.0697   0.060610
# 41      Edelweiss Mid Cap Fund - Direct Plan - Growth  0.0533   0.062695
# 48  DSP Natural Resources and New Energy Fund - Di...  0.0483   0.058763
# 43  ICICI Prudential Multicap Fund - Direct Plan -...  0.0373   0.026804
# 45     SBI Infrastructure Fund - Direct Plan - Growth  0.0394   0.050467
# 49  Canara Robeco Infrastructure - Direct Plan - G...  0.0765   0.087672
# 13         HSBC Flexi Cap Fund - Direct Plan - Growth  0.0508   0.062600
# 51  LIC MF Infrastructure Fund - Direct Plan - Growth  0.1295   0.144285
# 44  Kotak Infrastructure and Economic Reform Fund ...  0.1022   0.118066
# 46  Invesco India Infrastructure Fund - Direct Pla...  0.0938   0.073191
# 23    Nippon India Vision Fund - Direct Plan - Growth  0.0234  -0.028909
# 57     Nippon India Value Fund - Direct Plan - Growth  0.0333  -0.044113
# 55         Axis Small Cap Fund - Direct Plan - Growth  0.0709  -0.054015
# 42       Sundaram Mid Cap Fund - Direct Plan - Growth  0.0569  -0.101739
#
#        Error
# 39  0.000025
# 8   0.000036
# 56  0.000082
# 14  0.000250
# 4   0.000643
# 0   0.000788
# 28  0.000789
# 37  0.000809
# 34  0.000878
# 10  0.001085
# 1   0.001145
# 35  0.001208
# 30  0.001253
# 26  0.001494
# 32  0.001546
# 24  0.001612
# 2   0.001615
# 21  0.001947
# 3   0.002059
# 29  0.002256
# 22  0.002412
# 12  0.002493
# 33  0.002605
# 15  0.002622
# 7   0.002746
# 20  0.002850
# 19  0.002865
# 31  0.003197
# 27  0.003256
# 18  0.003477
# 38  0.003775
# 11  0.004260
# 52  0.004289
# 9   0.004470
# 6   0.004613
# 5   0.004708
# 16  0.005476
# 25  0.005827
# 54  0.006307
# 36  0.006524
# 50  0.007212
# 17  0.008150
# 47  0.008470
# 40  0.008637
# 53  0.009090
# 41  0.009395
# 48  0.010463
# 43  0.010496
# 45  0.011067
# 49  0.011172
# 13  0.011800
# 51  0.014785
# 44  0.015866
# 46  0.020609
# 23  0.052309
# 57  0.077413
# 55  0.124915
# 42  0.158639
#
# Mean Absolute Error: 0.0116

# %%
# import numpy as np
# import pandas as pd
# import tensorflow as tf
# from tensorflow.keras import layers, models
# from sklearn.preprocessing import MinMaxScaler

# # Load data (WITHOUT setting index during read)
# annual_df = pd.read_excel('cleaned_annual_returns.xlsx')
# monthly_df = pd.read_excel('cleaned_monthly_returns.xlsx')

# # Explicitly set index after loading
# annual_df = annual_df.set_index('Scheme Name')
# monthly_df = monthly_df.set_index('Scheme Name')

# # Verify data loading
# print("Annual Data Sample:")
# print(annual_df.head())
# print("\nMonthly Data Sample:")
# print(monthly_df.head())

# # Prepare sequences for each fund
# results = []
# for fund_name in annual_df.index:
#     try:
#         # Get all available data
#         annual_data = annual_df.loc[fund_name].values
#         monthly_data = monthly_df.loc[fund_name].values  # Includes May'25

#         X = np.concatenate([annual_data, monthly_data])

#         if np.isnan(X).any():
#             continue

#         # Normalize and reshape
#         scaler = MinMaxScaler()
#         X_scaled = scaler.fit_transform(X.reshape(-1, 1)).flatten()
#         X_reshaped = X_scaled.reshape(1, len(X), 1)

#         # Build and train model (same architecture)
#         inputs = layers.Input(shape=(len(X), 1))
#         x = layers.LSTM(32, return_sequences=True)(inputs)
#         x = layers.LSTM(16)(x)
#         x = layers.Dense(8, activation='relu')(x)
#         outputs = layers.Dense(1)(x)
#         model = models.Model(inputs, outputs)
#         model.compile(optimizer='adam', loss='mse')
#         model.fit(X_reshaped, np.array([0]), epochs=50, verbose=0)  # Dummy target

#         # Predict June'25
#         pred_scaled = model.predict(X_reshaped, verbose=0)[0][0]
#         pred = scaler.inverse_transform([[pred_scaled]])[0][0]

#         results.append({
#             'Fund': fund_name,
#             'Predicted_Jun_25': pred  # Only prediction available
#         })
#     except Exception as e:
#         print(f"Skipping {fund_name}: {str(e)}")
#         continue

# # Display predictions
# if results:
#     results_df = pd.DataFrame(results)
#     print("\nJune 2025 Return Predictions:")
#     print(results_df.sort_values('Predicted_Jun_25', ascending=False))
# else:
#     print("No valid predictions generated")
# Out:
# Annual Data Sample:
#                                                       2024    2023    2022  \
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth              0.1960  0.3809  0.1363
# Invesco India Contra Fund - Direct Plan - Growth    0.3597  0.2958  0.0509
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth  0.2256  0.2672  0.0773
# Franklin India ELSS Tax Saver Fund - Direct Pla...  0.2321  0.3236  0.0627
# HDFC ELSS Tax saver - Direct Plan - Growth          0.2196  0.3348  0.1114
#
#                                                       2021    2020    2019  \
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth              0.4911  0.3061 -0.0034
# Invesco India Contra Fund - Direct Plan - Growth    0.2949  0.2220  0.0710
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth  0.2354  0.1343 -0.0072
# Franklin India ELSS Tax Saver Fund - Direct Pla...  0.3576  0.1055  0.0633
# HDFC ELSS Tax saver - Direct Plan - Growth          0.3429  0.0586  0.0401
#
#                                                       2018    2017    2016  \
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth             -0.1355  0.4106  0.0240
# Invesco India Contra Fund - Direct Plan - Growth   -0.0132  0.4811  0.0795
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth  0.0104  0.2226  0.1235
# Franklin India ELSS Tax Saver Fund - Direct Pla... -0.0150  0.3048  0.0516
# HDFC ELSS Tax saver - Direct Plan - Growth         -0.0970  0.3961  0.0749
#
#                                                       2015    2014
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth              0.0012  0.4830
# Invesco India Contra Fund - Direct Plan - Growth    0.0525  0.6460
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth  0.0226  0.4013
# Franklin India ELSS Tax Saver Fund - Direct Pla...  0.0469  0.5784
# HDFC ELSS Tax saver - Direct Plan - Growth         -0.0607  0.5685
#
# Monthly Data Sample:
#                                                     May'25  Apr'25  Mar'25  \
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth              0.0236  0.0360  0.0507
# Invesco India Contra Fund - Direct Plan - Growth    0.0301  0.0516  0.0716
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth  0.0279  0.0384  0.0388
# Franklin India ELSS Tax Saver Fund - Direct Pla...  0.0241  0.0563  0.0647
# HDFC ELSS Tax saver - Direct Plan - Growth          0.0158  0.0564  0.0646
#
#                                                     Feb'25  Jan'25  Dec'24  \
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth             -0.0620 -0.0334 -0.0178
# Invesco India Contra Fund - Direct Plan - Growth   -0.0775 -0.0667 -0.0015
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth -0.0608 -0.0174 -0.0153
# Franklin India ELSS Tax Saver Fund - Direct Pla... -0.0686 -0.0559 -0.0014
# HDFC ELSS Tax saver - Direct Plan - Growth         -0.0499 -0.0257 -0.0136
#
#                                                     Nov'24  Oct'24  Sep'24  \
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth              0.0052 -0.0579  0.0130
# Invesco India Contra Fund - Direct Plan - Growth    0.0066 -0.0537  0.0301
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth  0.
# 39  Invesco India Mid Cap Fund - Direct Plan - Growth         -0.104637
# 38    Nippon India Growth Fund - Direct Plan - Growth         -0.106452
# 18        Bandhan Focused Fund - Direct Plan - Growth         -0.109724
# 12  Motilal Oswal Flexi Cap Fund - Direct Plan - G...         -0.119158
# 0              SBI Contra Fund - Direct Plan - Growth         -0.135374
# 16           HDFC Focused Fund - Direct Plan - Growth         -0.135404
# 42       Sundaram Mid Cap Fund - Direct Plan - Growth         -0.145580
# 41      Edelweiss Mid Cap Fund - Direct Plan - Growth         -0.145748
# 48  DSP Natural Resources and New Energy Fund - Di...         -0.146956
# 40   Motilal Oswal Midcap Fund - Direct Plan - Growth         -0.147418
# 51  LIC MF Infrastructure Fund - Direct Plan - Growth         -0.154373
# 54  Nippon India Small Cap Fund - Direct Plan - Gr...         -0.157548
# 46  Invesco India Infrastructure Fund - Direct Pla...         -0.158600
# 23    Nippon India Vision Fund - Direct Plan - Growth         -0.158784
# 53   HSBC Business Cycles Fund - Direct Plan - Growth         -0.164323
# 45     SBI Infrastructure Fund - Direct Plan - Growth         -0.173665
# 44  Kotak Infrastructure and Economic Reform Fund ...         -0.183617
# 49  Canara Robeco Infrastructure - Direct Plan - G...         -0.183801
# 50  Bank of India Manufacturing & Infrastructure F...         -0.220644

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.preprocessing import MinMaxScaler

# Load data (WITHOUT setting index during read)
annual_df = pd.read_excel('cleaned_annual_returns.xlsx')
monthly_df = pd.read_excel('cleaned_monthly_returns.xlsx')

# Explicitly set index after loading
annual_df = annual_df.set_index('Scheme Name')
monthly_df = monthly_df.set_index('Scheme Name')

# Get all monthly columns except May'25 (which is our target)
monthly_feature_columns = [col for col in monthly_df.columns if col != "May'25"]

# Verify data loading
print("Annual Data Sample:")
print(annual_df.head())
print("\nMonthly Features Sample (excluding May'25):")
print(monthly_df[monthly_feature_columns].head())

# Prepare sequences for each fund
results = []
for fund_name in annual_df.index:
    try:
        # Get annual data and monthly data EXCLUDING May'25
        annual_data = annual_df.loc[fund_name].values
        monthly_data = monthly_df.loc[fund_name, monthly_feature_columns].values

        # Combine features and get target (May'25)
        X = np.concatenate([annual_data, monthly_data])
        y = monthly_df.loc[fund_name, "May'25"]

        # Skip if any missing data
        if np.isnan(X).any() or np.isnan(y):
            continue

        # Normalize
        scaler = MinMaxScaler()
        X_scaled = scaler.fit_transform(X.reshape(-1, 1)).flatten()
        y_scaled = scaler.transform([[y]]).flatten()[0]

        # Reshape for TFT (1 sample, timesteps, 1 feature)
        X_reshaped = X_scaled.reshape(1, len(X), 1)

        # Build simple TFT model
        inputs = layers.Input(shape=(len(X), 1))
        x = layers.LSTM(32, return_sequences=True)(inputs)
        x = layers.LSTM(16)(x)
        x = layers.Dense(8, activation='relu')(x)
        outputs = layers.Dense(1)(x)
        model = models.Model(inputs, outputs)
        model.compile(optimizer='adam', loss='mse')

        # Train (just on this fund's data)
        model.fit(X_reshaped, np.array([y_scaled]), epochs=50, verbose=0)

        # Predict
        pred_scaled = model.predict(X_reshaped, verbose=0)[0][0]
        pred = scaler.inverse_transform([[pred_scaled]])[0][0]

        results.append({
            'Fund': fund_name,
            'Actual': y,
            'Predicted': pred,
            'Error': abs(pred - y)
        })
    except Exception as e:
        print(f"Skipping {fund_name} due to error: {str(e)}")
        continue

# Create and display results
if results:
    results_df = pd.DataFrame(results)
    print("\nPrediction Results (May'25 Actual vs Predicted):")
    print(results_df[['Fund', 'Actual', 'Predicted', 'Error']].sort_values('Error'))

    mae = results_df['Error'].mean()
    print(f"\nMean Absolute Error: {mae:.4f}")
    print(f"Median Absolute Error: {results_df['Error'].median():.4f}")
    print(f"Accuracy within ±0.02: {(results_df['Error'] <= 0.02).mean()*100:.1f}%")
else:
    print("No valid funds processed - check data loading")
# Out:
# Annual Data Sample:
#                                                       2024    2023    2022  \
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth              0.1960  0.3809  0.1363
# Invesco India Contra Fund - Direct Plan - Growth    0.3597  0.2958  0.0509
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth  0.2256  0.2672  0.0773
# Franklin India ELSS Tax Saver Fund - Direct Pla...  0.2321  0.3236  0.0627
# HDFC ELSS Tax saver - Direct Plan - Growth          0.2196  0.3348  0.1114
#
#                                                       2021    2020    2019  \
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth              0.4911  0.3061 -0.0034
# Invesco India Contra Fund - Direct Plan - Growth    0.2949  0.2220  0.0710
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth  0.2354  0.1343 -0.0072
# Franklin India ELSS Tax Saver Fund - Direct Pla...  0.3576  0.1055  0.0633
# HDFC ELSS Tax saver - Direct Plan - Growth          0.3429  0.0586  0.0401
#
#                                                       2018    2017    2016  \
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth             -0.1355  0.4106  0.0240
# Invesco India Contra Fund - Direct Plan - Growth   -0.0132  0.4811  0.0795
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth  0.0104  0.2226  0.1235
# Franklin India ELSS Tax Saver Fund - Direct Pla... -0.0150  0.3048  0.0516
# HDFC ELSS Tax saver - Direct Plan - Growth         -0.0970  0.3961  0.0749
#
#                                                       2015    2014
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth              0.0012  0.4830
# Invesco India Contra Fund - Direct Plan - Growth    0.0525  0.6460
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth  0.0226  0.4013
# Franklin India ELSS Tax Saver Fund - Direct Pla...  0.0469  0.5784
# HDFC ELSS Tax saver - Direct Plan - Growth         -0.0607  0.5685
#
# Monthly Features Sample (excluding May'25):
#                                                     Apr'25  Mar'25  Feb'25  \
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth              0.0360  0.0507 -0.0620
# Invesco India Contra Fund - Direct Plan - Growth    0.0516  0.0716 -0.0775
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth  0.0384  0.0388 -0.0608
# Franklin India ELSS Tax Saver Fund - Direct Pla...  0.0563  0.0647 -0.0686
# HDFC ELSS Tax saver - Direct Plan - Growth          0.0564  0.0646 -0.0499
#
#                                                     Jan'25  Dec'24  Nov'24  \
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth             -0.0334 -0.0178  0.0052
# Invesco India Contra Fund - Direct Plan - Growth   -0.0667 -0.0015  0.0066
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth -0.0174 -0.0153  0.0089
# Franklin India ELSS Tax Saver Fund - Direct Pla... -0.0559 -0.0014  0.0109
# HDFC ELSS Tax saver - Direct Plan - Growth         -0.0257 -0.0136  0.0007
#
#                                                     Oct'24  Sep'24  Aug'24  \
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth             -0.0579  0.0130  0.0100
# Invesco India Contra Fund - Direct Plan - Growth   -0.0537  0.0301  0.0293
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth -0.0432  0.0121  0.0242
# Franklin India ELSS Tax Saver Fund - Direct Pla... -0.0527  0.0200  0.0206
# HDFC ELSS Tax saver - Direct Plan - Growth         -0.0506  0.0230  0.0194
#
#                                                     Jul'24
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth              0.0434
# Invesco India Contra Fund - Direct Plan - Growth    0.0595
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth  0.0296
# Franklin India ELSS Tax Saver Fund - Direct Pla...  0.0399
# HDFC ELSS Tax saver - Direct Plan - Growth          0.
# 13         HSBC Flexi Cap Fund - Direct Plan - Growth  0.0508   0.057417
# 44  Kotak Infrastructure and Economic Reform Fund ...  0.1022   0.095071
# 42       Sundaram Mid Cap Fund - Direct Plan - Growth  0.0569   0.064336
# 50  Bank of India Manufacturing & Infrastructure F...  0.0779   0.070367
# 52   Sundaram Consumption Fund - Direct Plan - Growth  0.0126   0.004969
# 38    Nippon India Growth Fund - Direct Plan - Growth  0.0527   0.044216
# 37           HDFC Mid Cap Fund - Direct Plan - Growth  0.0586   0.067526
# 21  Bandhan Large & Mid Cap Fund - Direct Plan - G...  0.0410   0.029948
# 46  Invesco India Infrastructure Fund - Direct Pla...  0.0938   0.080809
# 49  Canara Robeco Infrastructure - Direct Plan - G...  0.0765   0.090811
# 51  LIC MF Infrastructure Fund - Direct Plan - Growth  0.1295   0.144153
# 0              SBI Contra Fund - Direct Plan - Growth  0.0236   0.002549
# 6   Baroda BNP Paribas ELSS Tax Saver Fund - Direc...  0.0363  -0.019319
# 35  Canara Robeco Large Cap Fund - Direct Plan - G...  0.0209  -0.039966
# 45     SBI Infrastructure Fund - Direct Plan - Growth  0.0394  -0.130450
#
#        Error
# 57  0.000085
# 53  0.000289
# 22  0.000304
# 3   0.000448
# 29  0.000486
# 11  0.000551
# 10  0.000657
# 12  0.000763
# 20  0.000840
# 30  0.000877
# 1   0.000889
# 40  0.000905
# 8   0.000945
# 26  0.001035
# 4   0.001038
# 16  0.001200
# 36  0.001284
# 33  0.001547
# 7   0.001668
# 55  0.001899
# 27  0.002008
# 32  0.002038
# 48  0.002109
# 17  0.002443
# 15  0.002525
# 2   0.002546
# 23  0.002861
# 56  0.002954
# 24  0.002970
# 14  0.003050
# 5   0.003101
# 28  0.003239
# 9   0.003521
# 18  0.003565
# 47  0.003704
# 43  0.003712
# 54  0.003856
# 19  0.003951
# 25  0.003970
# 34  0.004143
# 31  0.004370
# 39  0.004900
# 41  0.005695
# 13  0.006617
# 44  0.007129
# 42  0.007436
# 50  0.007533
# 52  0.007631
# 38  0.008484
# 37  0.008926
# 21  0.011052
# 46  0.012991
# 49  0.014311
# 51  0.014653
# 0   0.021051
# 6   0.055619
# 35  0.060866
# 45  0.169850
#
# Mean Absolute Error: 0.0088
# Median Absolute Error: 0.0030
# Accuracy within ±0.02: 93.1%

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models
from sklearn.preprocessing import MinMaxScaler

# Load data (WITHOUT setting index during read)
annual_df = pd.read_excel('cleaned_annual_returns.xlsx')
monthly_df = pd.read_excel('cleaned_monthly_returns.xlsx')

# Explicitly set index after loading
annual_df = annual_df.set_index('Scheme Name')
monthly_df = monthly_df.set_index('Scheme Name')

# Get all monthly columns except Jun'25 (which is our new target)
monthly_feature_columns = [col for col in monthly_df.columns if col != "Jun'25"]

print("Annual Data Sample:")
print(annual_df.head())
print("\nMonthly Features Sample (excluding Jun'25):")
print(monthly_df[monthly_feature_columns].head())

# Prepare sequences for each fund
results = []
for fund_name in annual_df.index:
    try:
        # Get annual and monthly data EXCLUDING Jun'25
        annual_data = annual_df.loc[fund_name].values
        monthly_data = monthly_df.loc[fund_name, monthly_feature_columns].values

        # Combine features
        X = np.concatenate([annual_data, monthly_data])

        # We try to get target (Jun'25), but it's okay if it's missing
        y = monthly_df.loc[fund_name, "Jun'25"] if "Jun'25" in monthly_df.columns else np.nan

        # Skip if input data is missing
        if np.isnan(X).any():
            continue

        # Normalize
        scaler = MinMaxScaler()
        X_scaled = scaler.fit_transform(X.reshape(-1, 1)).flatten()

        # If actual value exists, scale it too
        y_scaled = scaler.transform([[y]]).flatten()[0] if not np.isnan(y) else None

        # Reshape for TFT
        X_reshaped = X_scaled.reshape(1, len(X), 1)

        # Build model
        inputs = layers.Input(shape=(len(X), 1))
        x = layers.LSTM(32, return_sequences=True)(inputs)
        x = layers.LSTM(16)(x)
        x = layers.Dense(8, activation='relu')(x)
        outputs = layers.Dense(1)(x)
        model = models.Model(inputs, outputs)
        model.compile(optimizer='adam', loss='mse')

        # If actual value available, train on it
        if y_scaled is not None:
            model.fit(X_reshaped, np.array([y_scaled]), epochs=50, verbose=0)
        else:
            model.fit(X_reshaped, X_reshaped[:, -1, :], epochs=50, verbose=0)  # dummy train

        # Predict
        pred_scaled = model.predict(X_reshaped, verbose=0)[0][0]
        pred = scaler.inverse_transform([[pred_scaled]])[0][0]

        results.append({
            'Fund': fund_name,
            'Actual': y if not np.isnan(y) else 'N/A',
            'Predicted': pred,
            'Error': abs(pred - y) if not np.isnan(y) else 'N/A'
        })
    except Exception as e:
        print(f"Skipping {fund_name} due to error: {str(e)}")
        continue

# Display predictions
if results:
    results_df = pd.DataFrame(results)
    print("\nPrediction Results (Jun'25):")
    print(results_df[['Fund', 'Actual', 'Predicted', 'Error']])

    if results_df['Error'].dtype != 'O':  # Only if error is numeric
        mae = results_df['Error'].mean()
        print(f"\nMean Absolute Error: {mae:.4f}")
        print(f"Median Absolute Error: {results_df['Error'].median():.4f}")
        print(f"Accuracy within ±0.02: {(results_df['Error'] <= 0.02).mean()*100:.1f}%")
else:
    print("No valid funds processed.")
# Out:
# Annual Data Sample:
#                                                       2024    2023    2022  \
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth              0.1960  0.3809  0.1363
# Invesco India Contra Fund - Direct Plan - Growth    0.3597  0.2958  0.0509
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth  0.2256  0.2672  0.0773
# Franklin India ELSS Tax Saver Fund - Direct Pla...  0.2321  0.3236  0.0627
# HDFC ELSS Tax saver - Direct Plan - Growth          0.2196  0.3348  0.1114
#
#                                                       2021    2020    2019  \
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth              0.4911  0.3061 -0.0034
# Invesco India Contra Fund - Direct Plan - Growth    0.2949  0.2220  0.0710
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth  0.2354  0.1343 -0.0072
# Franklin India ELSS Tax Saver Fund - Direct Pla...  0.3576  0.1055  0.0633
# HDFC ELSS Tax saver - Direct Plan - Growth          0.3429  0.0586  0.0401
#
#                                                       2018    2017    2016  \
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth             -0.1355  0.4106  0.0240
# Invesco India Contra Fund - Direct Plan - Growth   -0.0132  0.4811  0.0795
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth  0.0104  0.2226  0.1235
# Franklin India ELSS Tax Saver Fund - Direct Pla... -0.0150  0.3048  0.0516
# HDFC ELSS Tax saver - Direct Plan - Growth         -0.0970  0.3961  0.0749
#
#                                                       2015    2014
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth              0.0012  0.4830
# Invesco India Contra Fund - Direct Plan - Growth    0.0525  0.6460
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth  0.0226  0.4013
# Franklin India ELSS Tax Saver Fund - Direct Pla...  0.0469  0.5784
# HDFC ELSS Tax saver - Direct Plan - Growth         -0.0607  0.5685
#
# Monthly Features Sample (excluding Jun'25):
#                                                     May'25  Apr'25  Mar'25  \
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth              0.0236  0.0360  0.0507
# Invesco India Contra Fund - Direct Plan - Growth    0.0301  0.0516  0.0716
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth  0.0279  0.0384  0.0388
# Franklin India ELSS Tax Saver Fund - Direct Pla...  0.0241  0.0563  0.0647
# HDFC ELSS Tax saver - Direct Plan - Growth          0.0158  0.0564  0.0646
#
#                                                     Feb'25  Jan'25  Dec'24  \
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth             -0.0620 -0.0334 -0.0178
# Invesco India Contra Fund - Direct Plan - Growth   -0.0775 -0.0667 -0.0015
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth -0.0608 -0.0174 -0.0153
# Franklin India ELSS Tax Saver Fund - Direct Pla... -0.0686 -0.0559 -0.0014
# HDFC ELSS Tax saver - Direct Plan - Growth         -0.0499 -0.0257 -0.0136
#
#                                                     Nov'24  Oct'24  Sep'24  \
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth              0.0052 -0.0579  0.0130
# Invesco India Contra Fund - Direct Plan - Growth    0.0066 -0.0537  0.0301
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth  0.0089 -0.0432  0.0121
# Franklin India ELSS Tax Saver Fund - Direct Pla...  0.0109 -0.0527  0.0200
# HDFC ELSS Tax saver - Direct Plan - Growth          0.0007 -0.0506  0.0230
#
#                                                     Aug'24  Jul'24
# Scheme Name
# SBI Contra Fund - Direct Plan - Growth              0.0100  0.0434
# Invesco India Contra Fund - Direct Plan - Growth    0.0293  0.0595
# Quantum ELSS Tax Saver Fund - Direct Plan - Growth  0.0242  0.0296
# Franklin India ELSS Tax Saver Fund - Direct Pla...  0.0206  0.0399
# HDFC ELSS Tax saver - Direct Plan - Growth          0.0194  0.0290
#
# Prediction Results (Jun'25):
#                                                  Fund Actual  Predicted Error
# 0              SBI Contra Fund - Direct Plan - Growth    N/A   0.040348   N/A
# 1    Invesco India Contra Fund - Direct Plan - Growth    N/A   0.056192   N/A
# 2   Quantum ELSS Tax Saver Fund - Direct Plan - Gr...    N/A   0.034117   N/A
# 3   Franklin India ELSS Tax Saver Fund - Direct Pl...    N/A   0.043243   N/A
# 4          HDFC ELSS Tax saver - Direct Plan - Growth    N/A   0.024358   N/A
# 5    SBI Long Term Equity Fund - Direct Plan - Growth    N/A   0.046337   N/A
# 6   Baroda BNP Paribas ELSS Tax Saver Fund - Direc...    N/A   0.015109   N/A
# 7      DSP ELSS Tax Saver Fund - Direct Plan - Growth    N/A   0.053175   N/A
# 8        LIC MF ELSS Tax Saver - Direct Plan - Growth    N/A   0.036002   N/A
# 9     Franklin India Flexi Cap Fund - Direct - Growth    N/A   0.045249   N/A
# 10         HDFC Flexi Cap Fund - Direct Plan - Growth    N/A   0.030538   N/A
# 11                JM Flexi Cap Fund - Direct - Growth    N/A   0.047049   N/A
# 12  Motilal Oswal Flexi Cap Fund - Direct Plan - G...    N/A   0.027544   N/A
# 13         HSBC Flexi Cap Fund - Direct Plan - Growth    N/A   0.034213   N/A
# 14  Parag Parikh Flexi Cap Fund - Direct Plan - Gr...    N/A   0.026317   N/A
# 15  ICICI Prudential Focused Equity Fund - Direct ...    N/A   0.057437   N/A
# 16           HDFC Focused Fund - Direct Plan - Growth    N/A   0.025353   N/A
# 17                JM Focused Fund - (Direct) - Growth    N/A   0.035312   N/A
# 18        Bandhan Focused Fund - Direct Plan - Growth    N/A   0.007067   N/A
# 19            DSP Focused Fund - Direct Plan - Growth    N/A   0.029708   N/A
# 20  ICICI Prudential Large & Mid Cap Fund- Direct ...    N/A   0.062487   N/A
